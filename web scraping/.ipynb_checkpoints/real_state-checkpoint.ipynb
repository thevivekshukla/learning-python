# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("http://pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c = r.content

soup = BeautifulSoup(c, "html.parser")
#print(soup.prettify())

all = soup.find_all('div', {"class":"propertyRow"})

all[0].find("h4", {"class":"propPrice"}).text.replace("\n", "").replace(" ", "")
# Out:
# '$725,000'

# %%
for item in all:
    print(item.find("h4", {"class":"propPrice"}).text.replace("\n","").replace(" ",""))
    print(item.find_all("span",{"class":"propAddressCollapse"})[0].text)
    print(item.find_all("span",{"class":"propAddressCollapse"})[1].text)
    try:
        print(item.find("span",{"class":"infoBed"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoSqFt"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoValueFullBath"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoValueHalfBath"}).find("b").text)
    except:
        print(None)
    
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        #print(column_group)
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}), column_group.find_all("span",{"class":"featureName"})):
            #print(feature_group.text, feature_name.text)
            if 'Lot Size' in feature_group.text:
                print(feature_name.text)
    print()
# Out:
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
# None
# None
# None
# None
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
# 4
# None
# 4
# None
# 0.21 Acres
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
# 5
# 3,154
# 3
# None
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
# 4
# 3,076
# 3
# 1
# Under 1/2 Acre,
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
# 3
# 1,172
# 3
# None
# Under 1/2 Acre,
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
# 4
# 1,932
# 2
# None
# 0.27 Acres
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
# 4
# 1,676
# 3
# None
# Under 1/2 Acre,
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
# 3
# 1,344
# 2
# None
# Under 1/2 Acre,
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
# 3
# 1,920
# 2
# None
# Under 1/2 Acre,
#
# $196,900
# 4 Minnies Lane
# Rock Springs, WY 82901
# 3
# 1,664
# 2
# None
# 2.02 Acres

# %%
li = []
for item in all:
    d = {}
    
    d["Price"] = item.find("h4", {"class":"propPrice"}).text.replace("\n","").replace(" ","")
    d["Address"] = item.find_all("span",{"class":"propAddressCollapse"})[0].text
    d["Locality"] = item.find_all("span",{"class":"propAddressCollapse"})[1].text
    try:
        d["Beds"] = item.find("span",{"class":"infoBed"}).find("b").text
    except:
        d["Beds"] = None
    try:
        d["Area"] = item.find("span",{"class":"infoSqFt"}).find("b").text
    except:
        d["Area"] = None
    try:
        d["Full Baths"] = item.find("span",{"class":"infoValueFullBath"}).find("b").text
    except:
        d["Full Baths"] = None
    try:
        d["Half Baths"] = item.find("span",{"class":"infoValueHalfBath"}).find("b").text
    except:
        d["Half Baths"] = None
    
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        #print(column_group)
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}), column_group.find_all("span",{"class":"featureName"})):
            #print(feature_group.text, feature_name.text)
            if 'Lot Size' in feature_group.text:
                d["Lot Size"] = feature_name.text
    print()
    
    li.append(d)
    print(li)
# Out:
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': '1', 'Area': '3,076', 'Beds': '4', 'Address': '3239 Spearhead Way', 'Price': '$389,900', 'Full Baths': '3'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': '1', 'Area': '3,076', 'Beds': '4', 'Address': '3239 Spearhead Way', 'Price': '$389,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,172', 'Beds': '3', 'Address': '522 Emerald Street', 'Price': '$254,000', 'Full Baths': '3'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': '1', 'Area': '3,076', 'Beds': '4', 'Address': '3239 Spearhead Way', 'Price': '$389,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,172', 'Beds': '3', 'Address': '522 Emerald Street', 'Price': '$254,000', 'Full Baths': '3'}, {'Lot Size': '0.27 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,932', 'Beds': '4', 'Address': "1302 Veteran's Drive", 'Price': '$252,900', 'Full Baths': '2'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': '1', 'Area': '3,076', 'Beds': '4', 'Address': '3239 Spearhead Way', 'Price': '$389,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,172', 'Beds': '3', 'Address': '522 Emerald Street', 'Price': '$254,000', 'Full Baths': '3'}, {'Lot Size': '0.27 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,932', 'Beds': '4', 'Address': "1302 Veteran's Drive", 'Price': '$252,900', 'Full Baths': '2'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,676', 'Beds': '4', 'Address': '1021 Cypress Cir', 'Price': '$210,000', 'Full Baths': '3'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': '1', 'Area': '3,076', 'Beds': '4', 'Address': '3239 Spearhead Way', 'Price': '$389,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,172', 'Beds': '3', 'Address': '522 Emerald Street', 'Price': '$254,000', 'Full Baths': '3'}, {'Lot Size': '0.27 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,932', 'Beds': '4', 'Address': "1302 Veteran's Drive", 'Price': '$252,900', 'Full Baths': '2'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,676', 'Beds': '4', 'Address': '1021 Cypress Cir', 'Price': '$210,000', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,344', 'Beds': '3', 'Address': '913 Madison Dr', 'Price': '$209,000', 'Full Baths': '2'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': '1', 'Area': '3,076', 'Beds': '4', 'Address': '3239 Spearhead Way', 'Price': '$389,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,172', 'Beds': '3', 'Address': '522 Emerald Street', 'Price': '$254,000', 'Full Baths': '3'}, {'Lot Size': '0.27 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,932', 'Beds': '4', 'Address': "1302 Veteran's Drive", 'Price': '$252,900', 'Full Baths': '2'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,676', 'Beds': '4', 'Address': '1021 Cypress Cir', 'Price': '$210,000', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,344', 'Beds': '3', 'Address': '913 Madison Dr', 'Price': '$209,000', 'Full Baths': '2'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,920', 'Beds': '3', 'Address': '1344 Teton Street', 'Price': '$199,900', 'Full Baths': '2'}]
#
# [{'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': None, 'Address': '0 Gateway', 'Price': '$725,000', 'Full Baths': None}, {'Lot Size': '0.21 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': None, 'Beds': '4', 'Address': '1003 Winchester Blvd.', 'Price': '$452,900', 'Full Baths': '4'}, {'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '3,154', 'Beds': '5', 'Address': '600 Talladega', 'Price': '$396,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': '1', 'Area': '3,076', 'Beds': '4', 'Address': '3239 Spearhead Way', 'Price': '$389,900', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,172', 'Beds': '3', 'Address': '522 Emerald Street', 'Price': '$254,000', 'Full Baths': '3'}, {'Lot Size': '0.27 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,932', 'Beds': '4', 'Address': "1302 Veteran's Drive", 'Price': '$252,900', 'Full Baths': '2'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,676', 'Beds': '4', 'Address': '1021 Cypress Cir', 'Price': '$210,000', 'Full Baths': '3'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,344', 'Beds': '3', 'Address': '913 Madison Dr', 'Price': '$209,000', 'Full Baths': '2'}, {'Lot Size': 'Under 1/2 Acre, ', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,920', 'Beds': '3', 'Address': '1344 Teton Street', 'Price': '$199,900', 'Full Baths': '2'}, {'Lot Size': '2.02 Acres', 'Locality': 'Rock Springs, WY 82901', 'Half Baths': None, 'Area': '1,664', 'Beds': '3', 'Address': '4 Minnies Lane', 'Price': '$196,900', 'Full Baths': '2'}]

# %%
li
# Out:
# [{'Address': '0 Gateway',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000'},
#  {'Address': '1003 Winchester Blvd.',
#   'Area': None,
#   'Beds': '4',
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': '0.21 Acres',
#   'Price': '$452,900'},
#  {'Address': '600 Talladega',
#   'Area': '3,154',
#   'Beds': '5',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900'},
#  {'Address': '3239 Spearhead Way',
#   'Area': '3,076',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$389,900'},
#  {'Address': '522 Emerald Street',
#   'Area': '1,172',
#   'Beds': '3',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$254,000'},
#  {'Address': "1302 Veteran's Drive",
#   'Area': '1,932',
#   'Beds': '4',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': '0.27 Acres',
#   'Price': '$252,900'},
#  {'Address': '1021 Cypress Cir',
#   'Area': '1,676',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$210,000'},
#  {'Address': '913 Madison Dr',
#   'Area': '1,344',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$209,000'},
#  {'Address': '1344 Teton Street',
#   'Area': '1,920',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$199,900'},
#  {'Address': '4 Minnies Lane',
#   'Area': '1,664',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': '2.02 Acres',
#   'Price': '$196,900'}]

# %%
import pandas
df = pandas.DataFrame(li)

# %%
df
# Out:
#                  Address   Area  Beds Full Baths Half Baths  \
# 0              0 Gateway   None  None       None       None
# 1  1003 Winchester Blvd.   None     4          4       None
# 2          600 Talladega  3,154     5          3       None
# 3     3239 Spearhead Way  3,076     4          3          1
# 4     522 Emerald Street  1,172     3          3       None
# 5   1302 Veteran's Drive  1,932     4          2       None
# 6       1021 Cypress Cir  1,676     4          3       None
# 7         913 Madison Dr  1,344     3          2       None
# 8      1344 Teton Street  1,920     3          2       None
# 9         4 Minnies Lane  1,664     3          2       None
#
#                  Locality          Lot Size     Price
# 0  Rock Springs, WY 82901               NaN  $725,000
# 1  Rock Springs, WY 82901        0.21 Acres  $452,900
# 2  Rock Springs, WY 82901               NaN  $396,900
# 3  Rock Springs, WY 82901  Under 1/2 Acre,   $389,900
# 4  Rock Springs, WY 82901  Under 1/2 Acre,   $254,000
# 5  Rock Springs, WY 82901        0.27 Acres  $252,900
# 6  Rock Springs, WY 82901  Under 1/2 Acre,   $210,000
# 7  Rock Springs, WY 82901  Under 1/2 Acre,   $209,000
# 8  Rock Springs, WY 82901  Under 1/2 Acre,   $199,900
# 9  Rock Springs, WY 82901        2.02 Acres  $196,900

# %%
df.to_csv('output.csv')
